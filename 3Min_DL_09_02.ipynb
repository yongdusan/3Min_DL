# %% [markdown]
# ### 골빈해커의 3분 딥러닝
# #### 9장 딥러닝의 미래 GAN

# %% [markdown]
# #### 원하는 숫자 생성

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)

total_epoch = 100
batch_size = 100
n_hidden = 256
n_input = 28 * 28
n_noise = 128
n_class = 10

X = tf.placeholder(tf.float32, [None, n_input])
# 노이즈와 실제 이미지에, 그에 해당하는 숫자에 대한 정보를 넣어주기 위해 사용합니다.
Y = tf.placeholder(tf.float32, [None, n_class])
Z = tf.placeholder(tf.float32, [None, n_noise])


def generator(noise, labels):
    with tf.variable_scope('generator'):
        # noise 값에 labels 정보를 추가
        inputs = tf.concat([noise, labels], 1)
        # TensorFlow 에서 제공하는 유틸리티 함수를 이용해 신경망을 매우 간단하게 구성 가능
        hidden = tf.layers.dense(inputs, n_hidden,
                                 activation=tf.nn.relu)
        output = tf.layers.dense(hidden, n_input,
                                 activation=tf.nn.sigmoid)

    return output


def discriminator(inputs, labels, reuse=None):
    with tf.variable_scope('discriminator') as scope:
        # 노이즈에서 생성한 이미지와 실제 이미지를 판별하는 모델의 변수를 동일하게 하기 위해,
        # 이전에 사용되었던 변수를 재사용하도록 합니다.
        if reuse:
            scope.reuse_variables()

        inputs = tf.concat([inputs, labels], 1)

        hidden = tf.layers.dense(inputs, n_hidden,
                                 activation=tf.nn.relu)
        output = tf.layers.dense(hidden, 1,
                                 activation=None)

    return output


def get_noise(batch_size, n_noise):
    return np.random.uniform(-1., 1., size=[batch_size, n_noise])

# 생성 모델과 판별 모델에 Y 즉, labels 정보를 추가하여
# labels 정보에 해당하는 이미지를 생성할 수 있도록 유도합니다.
G = generator(Z, Y)
D_real = discriminator(X, Y)
D_gene = discriminator(G, Y, True)

# 손실함수는 다음을 참고하여 GAN 논문에 나온 방식과는 약간 다르게 작성하였습니다.
# http://bamos.github.io/2016/08/09/deep-completion/
# 진짜 이미지를 판별하는 D_real 값은 1에 가깝도록,
# 가짜 이미지를 판별하는 D_gene 값은 0에 가깝도록 하는 손실 함수입니다.
loss_D_real = tf.reduce_mean(
                    tf.nn.sigmoid_cross_entropy_with_logits(
                        logits=D_real, labels=tf.ones_like(D_real)))
loss_D_gene = tf.reduce_mean(
                    tf.nn.sigmoid_cross_entropy_with_logits(
                        logits=D_gene, labels=tf.zeros_like(D_gene)))
# loss_D_real 과 loss_D_gene 을 더한 뒤 이 값을 최소화 하도록 최적화합니다.
loss_D = loss_D_real + loss_D_gene
# 가짜 이미지를 진짜에 가깝게 만들도록 생성망을 학습시키기 위해, D_gene 을 최대한 1에 가깝도록 만드는 손실함수입니다.
loss_G = tf.reduce_mean(
                    tf.nn.sigmoid_cross_entropy_with_logits(
                        logits=D_gene, labels=tf.ones_like(D_gene)))

# TensorFlow 에서 제공하는 유틸리티 함수를 이용해
# discriminator 와 generator scope 에서 사용된 변수들을 쉽게 가져올 수 있습니다.
vars_D = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,
                           scope='discriminator')
vars_G = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,
                           scope='generator')

train_D = tf.train.AdamOptimizer().minimize(loss_D,
                                            var_list=vars_D)
train_G = tf.train.AdamOptimizer().minimize(loss_G,
                                            var_list=vars_G)

#########
# 신경망 모델 학습
######
sess = tf.Session()
sess.run(tf.global_variables_initializer())

total_batch = int(mnist.train.num_examples/batch_size)
loss_val_D, loss_val_G = 0, 0

for epoch in range(total_epoch):
    for i in range(total_batch):
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        noise = get_noise(batch_size, n_noise)

        _, loss_val_D = sess.run([train_D, loss_D],
                                 feed_dict={X: batch_xs, Y: batch_ys, Z: noise})
        _, loss_val_G = sess.run([train_G, loss_G],
                                 feed_dict={Y: batch_ys, Z: noise})

    print('Epoch:', '%04d' % epoch,
          'D loss: {:.4}'.format(loss_val_D),
          'G loss: {:.4}'.format(loss_val_G))

    #########
    # 학습이 되어가는 모습을 보기 위해 주기적으로 레이블에 따른 이미지를 생성하여 저장
    ######
    if epoch == 0 or (epoch + 1) % 10 == 0:
        sample_size = 10
        noise = get_noise(sample_size, n_noise)
        samples = sess.run(G,
                           feed_dict={Y: mnist.test.labels[:sample_size],
                                      Z: noise})

        fig, ax = plt.subplots(2, sample_size, figsize=(sample_size, 2))

        for i in range(sample_size):
            ax[0][i].set_axis_off()
            ax[1][i].set_axis_off()

            ax[0][i].imshow(np.reshape(mnist.test.images[i], (28, 28)))
            ax[1][i].imshow(np.reshape(samples[i], (28, 28)))

        plt.savefig('samples2/{}.png'.format(str(epoch).zfill(3)), bbox_inches='tight')
        plt.close(fig)

print('최적화 완료!')
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz
# Epoch: 0000 D loss: 0.01216 G loss: 7.611
# Epoch: 0001 D loss: 0.01749 G loss: 8.613
# Epoch: 0002 D loss: 0.009398 G loss: 9.758
# Epoch: 0003 D loss: 0.003262 G loss: 9.127
# Epoch: 0004 D loss: 0.001877 G loss: 10.11
# Epoch: 0005 D loss: 0.001914 G loss: 10.3
# Epoch: 0006 D loss: 0.01182 G loss: 8.747
# Epoch: 0007 D loss: 0.002025 G loss: 10.0
# Epoch: 0008 D loss: 0.002015 G loss: 16.54
# Epoch: 0009 D loss: 0.028 G loss: 7.713
# Epoch: 0010 D loss: 0.02956 G loss: 6.719
# Epoch: 0011 D loss: 0.02911 G loss: 7.961
# Epoch: 0012 D loss: 0.02607 G loss: 7.99
# Epoch: 0013 D loss: 0.07132 G loss: 6.609
# Epoch: 0014 D loss: 0.0861 G loss: 5.962
# Epoch: 0015 D loss: 0.3543 G loss: 6.308
# Epoch: 0016 D loss: 0.2123 G loss: 4.761
# Epoch: 0017 D loss: 0.2362 G loss: 4.924
# Epoch: 0018 D loss: 0.3088 G loss: 4.892
# Epoch: 0019 D loss: 0.4331 G loss: 4.593
# Epoch: 0020 D loss: 0.4236 G loss: 3.44
# Epoch: 0021 D loss: 0.5032 G loss: 3.436
# Epoch: 0022 D loss: 0.6736 G loss: 2.954
# Epoch: 0023 D loss: 0.3888 G loss: 3.443
# Epoch: 0024 D loss: 0.4149 G loss: 3.194
# Epoch: 0025 D loss: 0.3224 G loss: 4.31
# Epoch: 0026 D loss: 0.4097 G loss: 3.491
# Epoch: 0027 D loss: 0.6174 G loss: 3.149
# Epoch: 0028 D loss: 0.6059 G loss: 2.669
# Epoch: 0029 D loss: 0.6725 G loss: 3.524
# Epoch: 0030 D loss: 0.6686 G loss: 2.886
# Epoch: 0031 D loss: 0.8649 G loss: 2.476
# Epoch: 0032 D loss: 0.8066 G loss: 2.796
# Epoch: 0033 D loss: 0.7937 G loss: 1.929
# Epoch: 0034 D loss: 0.6342 G loss: 2.641
# Epoch: 0035 D loss: 0.6329 G loss: 2.256
# Epoch: 0036 D loss: 0.7686 G loss: 2.342
# Epoch: 0037 D loss: 0.6839 G loss: 2.427
# Epoch: 0038 D loss: 0.622 G loss: 2.581
# Epoch: 0039 D loss: 0.495 G loss: 2.63
# Epoch: 0040 D loss: 0.54 G loss: 2.846
# Epoch: 0041 D loss: 0.7114 G loss: 2.293
# Epoch: 0042 D loss: 0.7454 G loss: 2.091
# Epoch: 0043 D loss: 0.7601 G loss: 2.154
# Epoch: 0044 D loss: 0.619 G loss: 2.566
# Epoch: 0045 D loss: 0.8303 G loss: 2.508
# Epoch: 0046 D loss: 0.7768 G loss: 2.128
# Epoch: 0047 D loss: 0.6832 G loss: 2.091
# Epoch: 0048 D loss: 0.6268 G loss: 1.989
# Epoch: 0049 D loss: 0.7601 G loss: 2.013
# Epoch: 0050 D loss: 0.6994 G loss: 2.1
# Epoch: 0051 D loss: 0.8245 G loss: 2.561
# Epoch: 0052 D loss: 0.8008 G loss: 1.863
# Epoch: 0053 D loss: 0.7068 G loss: 2.348
# Epoch: 0054 D loss: 0.6545 G loss: 2.237
# Epoch: 0055 D loss: 0.6687 G loss: 2.145
# Epoch: 0056 D loss: 0.7329 G loss: 2.13
# Epoch: 0057 D loss: 0.704 G loss: 2.475
# Epoch: 0058 D loss: 0.6174 G loss: 2.431
# Epoch: 0059 D loss: 0.7589 G loss: 2.07
# Epoch: 0060 D loss: 0.5896 G loss: 2.232
# Epoch: 0061 D loss: 0.8805 G loss: 2.09
# Epoch: 0062 D loss: 0.823 G loss: 1.948
# Epoch: 0063 D loss: 0.8476 G loss: 1.743
# Epoch: 0064 D loss: 0.7392 G loss: 2.435
# Epoch: 0065 D loss: 0.8166 G loss: 2.081
# Epoch: 0066 D loss: 0.6863 G loss: 2.28
# Epoch: 0067 D loss: 0.7863 G loss: 1.999
# Epoch: 0068 D loss: 0.7 G loss: 2.138
# Epoch: 0069 D loss: 0.7923 G loss: 1.861
# Epoch: 0070 D loss: 0.7345 G loss: 2.291
# Epoch: 0071 D loss: 0.7275 G loss: 2.085
# Epoch: 0072 D loss: 0.8324 G loss: 2.347
# Epoch: 0073 D loss: 0.8332 G loss: 1.966
# Epoch: 0074 D loss: 0.8602 G loss: 1.623
# Epoch: 0075 D loss: 0.6308 G loss: 2.386
# Epoch: 0076 D loss: 0.7725 G loss: 1.936
# Epoch: 0077 D loss: 0.7463 G loss: 2.32
# Epoch: 0078 D loss: 0.6961 G loss: 2.253
# Epoch: 0079 D loss: 0.6057 G loss: 2.379
# Epoch: 0080 D loss: 0.7293 G loss: 2.027
# Epoch: 0081 D loss: 0.7554 G loss: 1.986
# Epoch: 0082 D loss: 0.8315 G loss: 2.092
# Epoch: 0083 D loss: 0.8101 G loss: 1.974
# Epoch: 0084 D loss: 0.6893 G loss: 1.943
# Epoch: 0085 D loss: 0.722 G loss: 2.097
# Epoch: 0086 D loss: 0.7582 G loss: 1.871
# Epoch: 0087 D loss: 0.825 G loss: 1.877
# Epoch: 0088 D loss: 0.8693 G loss: 2.02
# Epoch: 0089 D loss: 0.7048 G loss: 2.233
# Epoch: 0090 D loss: 0.9399 G loss: 1.871
# Epoch: 0091 D loss: 0.886 G loss: 2.018
# Epoch: 0092 D loss: 0.7311 G loss: 2.138
# Epoch: 0093 D loss: 0.8518 G loss: 1.834
# Epoch: 0094 D loss: 0.7914 G loss: 2.442
# Epoch: 0095 D loss: 0.8694 G loss: 2.139
# Epoch: 0096 D loss: 0.7128 G loss: 1.853
# Epoch: 0097 D loss: 0.7011 G loss: 2.19
# Epoch: 0098 D loss: 0.745 G loss: 1.708
# Epoch: 0099 D loss: 0.7296 G loss: 2.192
# 최적화 완료!
