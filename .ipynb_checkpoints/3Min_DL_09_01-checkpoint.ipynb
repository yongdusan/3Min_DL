# %% [markdown]
# ### 골빈해커의 3분 딥러닝
# #### 9장 딥러닝의 미래 GAN

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz

# %%
# hyper parameters
total_epoch = 100
batch_size = 100
learning_rate = 0.0002
n_hidden = 256
n_input = 28 * 28
n_noise = 128 # 생성기의 입력값으로 사용할 노이즈의 크기

# 모델 구성
X = tf.placeholder(tf.float32, [None, n_input])
# 노이즈 Z를 입력값으로 사용합니다.
Z = tf.placeholder(tf.float32, [None, n_noise])
# 생성기 신경망에 사용하는 변수들
G_W1 = tf.Variable(tf.random_normal([n_noise, n_hidden], stddev=0.01))
G_b1 = tf.Variable(tf.zeros([n_hidden]))
G_W2 = tf.Variable(tf.random_normal([n_hidden, n_input], stddev=0.01))
G_b2 = tf.Variable(tf.zeros([n_input]))
# 판별기 신경망에 사용하는 변수들
D_W1 = tf.Variable(tf.random_normal([n_input, n_hidden], stddev=0.01))
D_b1 = tf.Variable(tf.zeros([n_hidden]))
# 판별기의 최종 결과값은 얼마나 진짜와 가깝냐를 판단하는 한 개의 스칼라값입니다.
D_W2 = tf.Variable(tf.random_normal([n_hidden, 1], stddev=0.01))
D_b2 = tf.Variable(tf.zeros([1]))

# 생성기(G) 신경망
def generator(noise_z):
    hidden = tf.nn.relu(
                    tf.matmul(noise_z, G_W1) + G_b1)
    output = tf.nn.sigmoid(
                    tf.matmul(hidden, G_W2) + G_b2)

    return output

# 판별기(D) 신경망
def discriminator(inputs):
    hidden = tf.nn.relu(
                    tf.matmul(inputs, D_W1) + D_b1)
    output = tf.nn.sigmoid(
                    tf.matmul(hidden, D_W2) + D_b2)

    return output

# 랜덤한 노이즈(Z)를 만듭니다.
def get_noise(batch_size, n_noise):
    return np.random.normal(size=(batch_size, n_noise))

# 노이즈를 이용해 랜덤한 이미지를 생성합니다.
G = generator(Z)
# 노이즈를 이용해 생성한 이미지가 진짜 이미지인지 판별한 값을 구합니다.
D_gene = discriminator(G)
# 진짜 이미지를 이용해 판별한 값을 구합니다.
D_real = discriminator(X)

# Loss function
# 논문에 따르면, GAN 모델의 최적화는 loss_G 와 loss_D 를 최대화 하는 것 입니다.
# 다만 loss_D와 loss_G는 서로 연관관계가 있기 때문에 두 개의 손실값이 항상 같이 증가하는 경향을 보이지는 않을 것 입니다.
# loss_D가 증가하려면 loss_G는 하락해야하고, loss_G가 증가하려면 loss_D는 하락해야하는 경쟁관계에 있기 때문입니다.
# 논문의 수식에 따른 다음 로직을 보면 loss_D 를 최대화하기 위해서는 D_gene 값(가짜 이미지 판별값)을 최소화하게 됩니다.
# 판별기에 진짜 이미지를 넣었을 때에도 최대값을 : tf.log(D_real)
# 가짜 이미지를 넣었을 때에도 최대값을 : tf.log(1 - D_gene)
# 갖도록 학습시키기 때문입니다.
# 이것은 판별기는 생성기가 만들어낸 이미지가 가짜라고 판단하도록 판별기 신경망을 학습시킵니다.
loss_D = tf.reduce_mean(tf.log(D_real) + tf.log(1 - D_gene))
# 반면 loss_G 를 최대화하기 위해서는 D_gene 값을 최대화하게 되는데,
# 이것은 가짜 이미지를 넣었을 때, 판별기가 최대한 실제 이미지라고 판단(1에 가깝게)하도록 생성기 신경망을 학습시킵니다.
# 논문에서는 loss_D 와 같은 수식으로 최소화 하는 생성기를 찾지만,
# 결국 D_gene 값을 최대화하는 것이므로 다음과 같이 사용할 수 있습니다.
loss_G = tf.reduce_mean(tf.log(D_gene))

# loss_D 를 구할 때는 판별기 신경망에 사용되는 변수만 사용하고,
# loss_G 를 구할 때는 생성기 신경망에 사용되는 변수만 사용하여 최적화를 합니다.
D_var_list = [D_W1, D_b1, D_W2, D_b2]
G_var_list = [G_W1, G_b1, G_W2, G_b2]

# GAN 논문의 수식에 따르면 loss 를 극대화 해야하지만, minimize 하는 최적화 함수를 사용하기 때문에
# 최적화 하려는 loss_D 와 loss_G 에 음수 부호를 붙여줍니다.
train_D = tf.train.AdamOptimizer(learning_rate).minimize(-loss_D,
                                                         var_list=D_var_list)
train_G = tf.train.AdamOptimizer(learning_rate).minimize(-loss_G,
                                                         var_list=G_var_list)

# %%
# 모델 학습
sess = tf.Session()
sess.run(tf.global_variables_initializer())

total_batch = int(mnist.train.num_examples/batch_size)
loss_val_D, loss_val_G = 0, 0

for epoch in range(total_epoch):
    for i in range(total_batch):
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        noise = get_noise(batch_size, n_noise)

        # 판별기와 생성기 신경망을 각각 학습
        _, loss_val_D = sess.run([train_D, loss_D],
                                 feed_dict={X: batch_xs, Z: noise})
        _, loss_val_G = sess.run([train_G, loss_G],
                                 feed_dict={Z: noise})

    print('Epoch:', '%04d' % epoch,
          'D loss: {:.4}'.format(loss_val_D),
          'G loss: {:.4}'.format(loss_val_G))

    if epoch == 0 or (epoch + 1) % 10 == 0:
        sample_size = 10
        noise = get_noise(sample_size, n_noise)
        samples = sess.run(G, feed_dict={Z: noise})

        fig, ax = plt.subplots(1, sample_size, figsize=(sample_size, 1))

        for i in range(sample_size):
            ax[i].set_axis_off()
            ax[i].imshow(np.reshape(samples[i], (28, 28)))

        plt.savefig('samples/{}.png'.format(str(epoch).zfill(3)), bbox_inches='tight')
        plt.close(fig)

print('최적화 완료!')
# Out:
# Epoch: 0000 D loss: -0.495 G loss: -1.971
# Epoch: 0001 D loss: -0.4329 G loss: -2.111
# Epoch: 0002 D loss: -0.2428 G loss: -2.462
# Epoch: 0003 D loss: -0.447 G loss: -1.611
# Epoch: 0004 D loss: -0.3547 G loss: -2.083
# Epoch: 0005 D loss: -0.2781 G loss: -2.954
# Epoch: 0006 D loss: -0.3024 G loss: -2.416
# Epoch: 0007 D loss: -0.1758 G loss: -2.84
# Epoch: 0008 D loss: -0.3187 G loss: -2.715
# Epoch: 0009 D loss: -0.3085 G loss: -2.288
# Epoch: 0010 D loss: -0.3912 G loss: -2.589
# Epoch: 0011 D loss: -0.5146 G loss: -2.275
# Epoch: 0012 D loss: -0.3147 G loss: -2.304
# Epoch: 0013 D loss: -0.3799 G loss: -2.193
# Epoch: 0014 D loss: -0.4649 G loss: -2.258
# Epoch: 0015 D loss: -0.5156 G loss: -2.165
# Epoch: 0016 D loss: -0.3766 G loss: -2.424
# Epoch: 0017 D loss: -0.486 G loss: -2.324
# Epoch: 0018 D loss: -0.531 G loss: -1.984
# Epoch: 0019 D loss: -0.5302 G loss: -2.467
# Epoch: 0020 D loss: -0.5537 G loss: -2.429
# Epoch: 0021 D loss: -0.5312 G loss: -2.287
# Epoch: 0022 D loss: -0.5423 G loss: -2.207
# Epoch: 0023 D loss: -0.3301 G loss: -2.426
# Epoch: 0024 D loss: -0.3743 G loss: -2.627
# Epoch: 0025 D loss: -0.413 G loss: -2.202
# Epoch: 0026 D loss: -0.3907 G loss: -2.768
# Epoch: 0027 D loss: -0.4273 G loss: -2.452
# Epoch: 0028 D loss: -0.415 G loss: -2.916
# Epoch: 0029 D loss: -0.4872 G loss: -2.399
# Epoch: 0030 D loss: -0.4635 G loss: -2.599
# Epoch: 0031 D loss: -0.395 G loss: -2.382
# Epoch: 0032 D loss: -0.6863 G loss: -2.3
# Epoch: 0033 D loss: -0.381 G loss: -2.595
# Epoch: 0034 D loss: -0.5963 G loss: -2.292
# Epoch: 0035 D loss: -0.433 G loss: -2.456
# Epoch: 0036 D loss: -0.624 G loss: -2.156
# Epoch: 0037 D loss: -0.5947 G loss: -2.228
# Epoch: 0038 D loss: -0.6081 G loss: -2.328
# Epoch: 0039 D loss: -0.6223 G loss: -2.452
# Epoch: 0040 D loss: -0.7223 G loss: -2.566
# Epoch: 0041 D loss: -0.517 G loss: -2.47
# Epoch: 0042 D loss: -0.4864 G loss: -2.341
# Epoch: 0043 D loss: -0.5654 G loss: -2.183
# Epoch: 0044 D loss: -0.5941 G loss: -2.343
# Epoch: 0045 D loss: -0.6594 G loss: -2.094
# Epoch: 0046 D loss: -0.6122 G loss: -2.038
# Epoch: 0047 D loss: -0.7831 G loss: -1.756
# Epoch: 0048 D loss: -0.7775 G loss: -1.995
# Epoch: 0049 D loss: -0.7702 G loss: -1.849
# Epoch: 0050 D loss: -1.011 G loss: -1.818
# Epoch: 0051 D loss: -0.863 G loss: -2.047
# Epoch: 0052 D loss: -0.9174 G loss: -1.916
# Epoch: 0053 D loss: -0.7037 G loss: -1.855
# Epoch: 0054 D loss: -0.7803 G loss: -1.643
# Epoch: 0055 D loss: -0.7407 G loss: -1.774
# Epoch: 0056 D loss: -0.8086 G loss: -2.109
# Epoch: 0057 D loss: -0.8141 G loss: -1.752
# Epoch: 0058 D loss: -0.7163 G loss: -1.946
# Epoch: 0059 D loss: -0.6899 G loss: -1.979
# Epoch: 0060 D loss: -0.7933 G loss: -1.663
# Epoch: 0061 D loss: -0.7246 G loss: -1.671
# Epoch: 0062 D loss: -0.89 G loss: -1.83
# Epoch: 0063 D loss: -0.7773 G loss: -1.88
# Epoch: 0064 D loss: -0.8734 G loss: -1.851
# Epoch: 0065 D loss: -0.6025 G loss: -1.858
# Epoch: 0066 D loss: -0.7611 G loss: -1.895
# Epoch: 0067 D loss: -0.8037 G loss: -1.654
# Epoch: 0068 D loss: -0.9317 G loss: -1.781
# Epoch: 0069 D loss: -0.8628 G loss: -1.76
# Epoch: 0070 D loss: -0.8313 G loss: -1.707
# Epoch: 0071 D loss: -0.7863 G loss: -1.738
# Epoch: 0072 D loss: -0.7825 G loss: -1.687
# Epoch: 0073 D loss: -0.8684 G loss: -1.684
# Epoch: 0074 D loss: -0.8577 G loss: -1.813
# Epoch: 0075 D loss: -0.7359 G loss: -1.821
# Epoch: 0076 D loss: -0.7626 G loss: -1.92
# Epoch: 0077 D loss: -0.691 G loss: -1.838
# Epoch: 0078 D loss: -0.759 G loss: -1.792
# Epoch: 0079 D loss: -0.8789 G loss: -1.868
# Epoch: 0080 D loss: -0.8753 G loss: -2.01
# Epoch: 0081 D loss: -0.707 G loss: -1.959
# Epoch: 0082 D loss: -0.8948 G loss: -1.698
# Epoch: 0083 D loss: -0.8373 G loss: -1.857
# Epoch: 0084 D loss: -0.9645 G loss: -1.802
# Epoch: 0085 D loss: -0.8512 G loss: -1.78
# Epoch: 0086 D loss: -0.959 G loss: -1.461
# Epoch: 0087 D loss: -0.8177 G loss: -1.801
# Epoch: 0088 D loss: -0.7972 G loss: -1.709
# Epoch: 0089 D loss: -0.7247 G loss: -1.726
# Epoch: 0090 D loss: -0.8609 G loss: -1.809
# Epoch: 0091 D loss: -0.8165 G loss: -1.721
# Epoch: 0092 D loss: -0.7265 G loss: -1.773
# Epoch: 0093 D loss: -0.9367 G loss: -1.777
# Epoch: 0094 D loss: -0.8789 G loss: -1.664
# Epoch: 0095 D loss: -0.954 G loss: -1.801
# Epoch: 0096 D loss: -0.8278 G loss: -1.529
# Epoch: 0097 D loss: -0.8614 G loss: -1.855
# Epoch: 0098 D loss: -0.8173 G loss: -1.562
# Epoch: 0099 D loss: -0.9113 G loss: -1.556
# 최적화 완료!
